# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X = dataset.iloc[:, 3:5].values

# %%
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import MeanShift
import matplotlib.pyplot as plt

# Initialize Mean Shift with default parameters
mean_shift = MeanShift()

# Fit the Mean Shift model
mean_shift.fit(X)

# Get the cluster centers and labels
cluster_centers = mean_shift.cluster_centers_
labels = mean_shift.labels_

# Plotting (if you want to visualize cluster centers)
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='red', s=200, alpha=0.75)
plt.title('Mean Shift Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# Optionally, print the number of clusters found
num_clusters = len(set(labels))
print(f'Number of clusters found: {num_clusters}')
# Out:
# Number of clusters found: 1

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth
import matplotlib.pyplot as plt
import numpy as np

# Define a range of bandwidth values to test
bandwidth_values = np.linspace(0.1, 2.0, 10)

# Initialize lists to store results
num_clusters_list = []

# Perform Mean Shift clustering for each bandwidth value
for bandwidth in bandwidth_values:
    mean_shift = MeanShift(bandwidth=bandwidth)
    mean_shift.fit(X)
    
    # Number of clusters found
    num_clusters = len(set(mean_shift.labels_))
    num_clusters_list.append(num_clusters)
    
    # Optional: Print or store the number of clusters for each bandwidth
    print(f'Bandwidth: {bandwidth:.2f} -> Number of clusters: {num_clusters}')

# Plotting the number of clusters found for each bandwidth
plt.plot(bandwidth_values, num_clusters_list, marker='o')
plt.title('Number of Clusters vs. Bandwidth')
plt.xlabel('Bandwidth')
plt.ylabel('Number of Clusters')
plt.grid(True)
plt.show()

# Optional: Choose the best bandwidth based on the plot or some criteria
# For example, you might choose the bandwidth with a specific number of clusters or based on other criteria.
best_bandwidth = bandwidth_values[np.argmin(np.abs(np.array(num_clusters_list) - target_num_clusters))]
print(f'Best bandwidth based on target number of clusters: {best_bandwidth:.2f}')
# Out:
# Bandwidth: 0.10 -> Number of clusters: 196
# Bandwidth: 0.31 -> Number of clusters: 196
# Bandwidth: 0.52 -> Number of clusters: 196
# Bandwidth: 0.73 -> Number of clusters: 196
# Bandwidth: 0.94 -> Number of clusters: 196
# Bandwidth: 1.16 -> Number of clusters: 172
# Bandwidth: 1.37 -> Number of clusters: 171
# Bandwidth: 1.58 -> Number of clusters: 155
# Bandwidth: 1.79 -> Number of clusters: 154
# Bandwidth: 2.00 -> Number of clusters: 138
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 33
#      29 plt.show()
#      31 # Optional: Choose the best bandwidth based on the plot or some criteria
#      32 # For example, you might choose the bandwidth with a specific number of clusters or based on other criteria.
# ---> 33 best_bandwidth = bandwidth_values[np.argmin(np.abs(np.array(num_clusters_list) - target_num_clusters))]
# ...

# %%
from sklearn.cluster import MeanShift
import matplotlib.pyplot as plt
import numpy as np

# Define a range of bandwidth values to test
bandwidth_values = np.linspace(0.1, 2.0, 10)

# Initialize lists to store results
num_clusters_list = []

# Perform Mean Shift clustering for each bandwidth value
for bandwidth in bandwidth_values:
    mean_shift = MeanShift(bandwidth=bandwidth)
    mean_shift.fit(X)
    
    # Number of clusters found
    num_clusters = len(set(mean_shift.labels_))
    num_clusters_list.append(num_clusters)
    
    # Optional: Print or store the number of clusters for each bandwidth
    print(f'Bandwidth: {bandwidth:.2f} -> Number of clusters: {num_clusters}')

# Plotting the number of clusters found for each bandwidth
plt.plot(bandwidth_values, num_clusters_list, marker='o')
plt.title('Number of Clusters vs. Bandwidth')
plt.xlabel('Bandwidth')
plt.ylabel('Number of Clusters')
plt.grid(True)
plt.show()
# Out:
# Bandwidth: 0.10 -> Number of clusters: 196
# Bandwidth: 0.31 -> Number of clusters: 196
# Bandwidth: 0.52 -> Number of clusters: 196
# Bandwidth: 0.73 -> Number of clusters: 196
# Bandwidth: 0.94 -> Number of clusters: 196
# Bandwidth: 1.16 -> Number of clusters: 172
# Bandwidth: 1.37 -> Number of clusters: 171
# Bandwidth: 1.58 -> Number of clusters: 155
# Bandwidth: 1.79 -> Number of clusters: 154
# Bandwidth: 2.00 -> Number of clusters: 138

# %%
from sklearn.cluster import MeanShift
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# Define a range of bandwidth values to test
bandwidth_values = np.linspace(0.1, 2.0, 10)

# Initialize lists to store results
num_clusters_list = []

# Perform Mean Shift clustering for each bandwidth value
for bandwidth in bandwidth_values:
    mean_shift = MeanShift(bandwidth=bandwidth)
    mean_shift.fit(X)
    
    # Number of clusters found
    num_clusters = len(set(mean_shift.labels_))
    num_clusters_list.append(num_clusters)
    
    # Optional: Print or store the number of clusters for each bandwidth
    print(f'Bandwidth: {bandwidth:.2f} -> Number of clusters: {num_clusters}')

# Plotting the number of clusters found for each bandwidth
plt.plot(bandwidth_values, num_clusters_list, marker='o')
plt.title('Number of Clusters vs. Bandwidth')
plt.xlabel('Bandwidth')
plt.ylabel('Number of Clusters')
plt.grid(True)
plt.show()

# Use the best bandwidth found (for example, the first one)
best_bandwidth = bandwidth_values[0]
mean_shift = MeanShift(bandwidth=best_bandwidth)
mean_shift.fit(X)

# Reduce dimensions to 2D for visualization
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X)

# Get the cluster centers and labels
cluster_centers = mean_shift.cluster_centers_
labels = mean_shift.labels_

# Reduce the cluster centers to 2D
cluster_centers_reduced = pca.transform(cluster_centers)

# Plot clusters
plt.figure(figsize=(10, 7))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=labels, s=50, cmap='viridis', label='Data Points')
plt.scatter(cluster_centers_reduced[:, 0], cluster_centers_reduced[:, 1], c='red', s=200, alpha=0.75, marker='x', label='Cluster Centers')
plt.title('Mean Shift Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Out:
# Bandwidth: 0.10 -> Number of clusters: 196
# Bandwidth: 0.31 -> Number of clusters: 196
# Bandwidth: 0.52 -> Number of clusters: 196
# Bandwidth: 0.73 -> Number of clusters: 196
# Bandwidth: 0.94 -> Number of clusters: 196
# Bandwidth: 1.16 -> Number of clusters: 172
# Bandwidth: 1.37 -> Number of clusters: 171
# Bandwidth: 1.58 -> Number of clusters: 155
# Bandwidth: 1.79 -> Number of clusters: 154
# Bandwidth: 2.00 -> Number of clusters: 138
